# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import re
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
data = pd.read_csv("/Users/triptibhardwaj/Downloads/DelhiNCR Restaurants.csv")
data
# Out:
#              Restaurant_Name  \
# 0                   Rustom's
# 1                  Cafe Lota
# 2     Dum-Pukht - ITC Maurya
# 3                Burma Burma
# 4              The Big Chill
# ...                      ...
# 1960          Bablu Chic-Inn
# 1961               Kovilakam
# 1962        Krips Restaurant
# 1963                Cafe 147
# 1964                Pizzasia
#
#                                                Category  Pricing_for_2  \
# 0     Parsi, Street Food, North Indian, Desserts, Be...           2100
# 1           Cafe, South Indian, North Indian, Beverages           1200
# 2                       Mughlai, North Indian, Desserts           5000
# 3           Asian, Burmese, Bubble Tea, Desserts, Salad           1600
# 4                        Continental, American, Italian           1500
# ...                                                 ...            ...
# 1960          Mughlai, North Indian, Chinese, Fast Food            500
# 1961                                       South Indian            350
# 1962                     North Indian, Chinese, Mughlai            900
# 1963  Cafe, North Indian, Chinese, Kashmiri, Rolls, ...            800
# 1964                        Pizza, Fast Food, Beverages            500
#
#                                          Locality  Dining_Rating  \
# 0                                  ITO, New Delhi            4.9
# 1                       Pragati Maidan, New Delhi            4.9
# 2             ITC Maurya, Chanakyapuri, New Delhi            4.9
# 3              Cyber Hub, DLF Cyber City, Gurgaon            4.9
# 4                          Khan Market, New Delhi            4.9
# ...                                           ...            ...
# 1960               Ashok Vihar Phase 3, New Delhi            3.9
# 1961                    Dilshad Garden, New Delhi            3.9
# 1962   Basant Lok Market, Vasant Vihar, New Delhi            3.9
# 1963                      Sainik Farms, New Delhi            3.9
# 1964                   Gaur City 2, Greater Noida            3.9
#
#       Dining_Review_Count  Delivery_Rating  Delivery_Rating_Count  \
# 0                    1885              4.4                   1844
# 1                    3748              3.9                     37
# 2                    1371              NaN                      0
# 3                    2636              4.4                   1238
# 4                    6487              NaN                      0
# ...                   ...              ...                    ...
# 1960                  183              4.1                    545
# 1961                  114              NaN                      1
# 1962                  316              3.9                   2977
# 1963                  120              3.8                    196
# 1964                  165              3.9                   5196
#
#                                                 Website  \
# 0      https://www.zomato.com/ncr/rustoms-ito-new-delhi
# 1     https://www.zomato.com/ncr/cafe-lota-pragati-m...
# 2     https://www.zomato.com/ncr/dum-pukht-itc-maury...
# 3     https://www.zomato.com/ncr/burma-burma-dlf-cyb...
# 4     https://www.zomato.com/ncr/the-big-chill-khan-...
# ...                                                 ...
# 1960  https://www.zomato.com/ncr/bablu-chic-inn-asho...
# 1961  https://www.zomato.com/ncr/kovilakam-dilshad-g...
# 1962  https://www.zomato.com/ncr/krips-restaurant-va...
# 1963  https://www.zomato.com/ncr/cafe-147-sainik-far...
# 1964  https://www.zomato.com/ncr/pizzasia-gaur-city-...
#
#                                                 Address     Phone_No  \
# 0     Delhi Parsi Anjuman, LNJP Colony, Bahadur Shah...   9.1991E+11
# 1     National Crafts Museum, Gate 2, Bhairon Marg, ...  9.17839E+11
# 2                   ITC Maurya, Chanakyapuri, New Delhi  9.11146E+11
# 3     Shop 6, Ground Floor, Building 8, Tower C, Cyb...  9.11244E+11
# 4                          68-A, Khan Market, New Delhi  9.11142E+11
# ...                                                 ...          ...
# 1960  Shop 9, Pocket B, DDA Market, Ashok Vihar Phas...      9.2E+11
# 1961  F-1, Lower Ground 2, Mrignaini Chowk, Dilshad ...  9.19654E+11
# 1962  59, Community Centre, Basant Lok Market, Vasan...  9.11141E+11
# 1963  Shop A1/7, Ground Floor, Main IGNOU Road, Neb ...  9.19812E+11
# 1964  Shop 14, Ground Floor, Bhawishya India Tower, ...  9.18861E+11
#
#        Latitude  Longitude                                         Known_For2  \
# 0     28.638167  77.240472                                                NaN
# 1     28.613429  77.242471  Pondicherry Fish Curry, Coconut Rabdi, Sabudan...
# 2     28.598200  77.173661  Royal ambiance and Mughlai cuisine, also recei...
# 3     28.494464  77.088532  Coconut Milk Dessert, Honey Caviar, Kaffir Lim...
# 4     28.600350  77.227493  Irish Cream Tiramisu, Penne Vodka, Mississippi...
# ...         ...        ...                                                ...
# 1960  28.692473  77.178004  Great Recommendations, Tamper Proof Packaging,...
# 1961  28.684101  77.326725  Kerala Parotta, Roasted Chicken, Chicken Curry...
# 1962  28.557310  77.163943  Excellent Food, Good Ambience, Courteous Staff...
# 1963  28.510338  77.202056  Pool, Live Music, Cafe, Environment, Good Plac...
# 1964  28.618250  77.427417  Cordial Staff, Great Recommendations, Mouth Wa...
#
#                                             Known_For22
# 0                                                   NaN
# 1     Artistic Decor, The Service, Natural Ambience,...
# 2                                                   NaN
# 3     Knowledgeable Staff, Authentic, Soothing Ambie...
# 4     Retro Ambience, Yummy Desserts, Big Portions, ...
# ...                                                 ...
# 1960                                                NaN
# 1961  Lip Smacking Food, Amazing Food, Owner, Good P...
# 1962                                                NaN
# 1963                                                NaN
# 1964                                                NaN
#
# [1965 rows x 15 columns]

# %%
print(data.isnull().sum())
# Out:
# Restaurant_Name            0
# Category                   0
# Pricing_for_2              0
# Locality                   0
# Dining_Rating              0
# Dining_Review_Count        0
# Delivery_Rating          402
# Delivery_Rating_Count      0
# Website                    0
# Address                    0
# Phone_No                   0
# Latitude                   0
# Longitude                  0
# Known_For2               405
# Known_For22              841
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1965 entries, 0 to 1964
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Restaurant_Name        1965 non-null   object
#  1   Category               1965 non-null   object
#  2   Pricing_for_2          1965 non-null   int64
#  3   Locality               1965 non-null   object
#  4   Dining_Rating          1965 non-null   float64
#  5   Dining_Review_Count    1965 non-null   int64
#  6   Delivery_Rating        1563 non-null   float64
#  7   Delivery_Rating_Count  1965 non-null   int64
#  8   Website                1965 non-null   object
#  9   Address                1965 non-null   object
#  10  Phone_No               1965 non-null   object
#  11  Latitude               1965 non-null   float64
#  12  Longitude              1965 non-null   float64
#  13  Known_For2             1560 non-null   object
#  14  Known_For22            1124 non-null   object
# dtypes: float64(4), int64(3), object(8)
# memory usage: 230.4+ KB

# %%
data.describe()
# Out:
#        Pricing_for_2  Dining_Rating  Dining_Review_Count  Delivery_Rating  \
# count    1965.000000    1965.000000          1965.000000      1563.000000
# mean     1090.687023       4.140000           721.954198         3.964299
# std       934.481617       0.202147           932.618839         0.242305
# min       100.000000       3.900000             3.000000         2.800000
# 25%       500.000000       4.000000           244.000000         3.800000
# 50%       700.000000       4.100000           433.000000         4.000000
# 75%      1500.000000       4.300000           842.000000         4.100000
# max      8000.000000       4.900000         10100.000000         4.500000
#
#        Delivery_Rating_Count     Latitude    Longitude
# count            1965.000000  1965.000000  1965.000000
# mean             3029.550636    28.549542    77.161570
# std              6529.839896     0.784241     1.685399
# min                 0.000000    -5.975200     2.650463
# 25%                34.000000    28.496564    77.100745
# 50%               604.000000    28.567882    77.201558
# 75%              3316.000000    28.635845    77.258408
# max             87700.000000    29.065189    77.536009

# %%
data=data.drop(['Dining_Review_Count','Delivery_Rating','Delivery_Rating_Count','Website','Address','Phone_No','Latitude','Longitude','Known_For2'],axis=1)

# %%
data
# Out:
#              Restaurant_Name  \
# 0                   Rustom's
# 1                  Cafe Lota
# 2     Dum-Pukht - ITC Maurya
# 3                Burma Burma
# 4              The Big Chill
# ...                      ...
# 1960          Bablu Chic-Inn
# 1961               Kovilakam
# 1962        Krips Restaurant
# 1963                Cafe 147
# 1964                Pizzasia
#
#                                                Category  Pricing_for_2  \
# 0     Parsi, Street Food, North Indian, Desserts, Be...           2100
# 1           Cafe, South Indian, North Indian, Beverages           1200
# 2                       Mughlai, North Indian, Desserts           5000
# 3           Asian, Burmese, Bubble Tea, Desserts, Salad           1600
# 4                        Continental, American, Italian           1500
# ...                                                 ...            ...
# 1960          Mughlai, North Indian, Chinese, Fast Food            500
# 1961                                       South Indian            350
# 1962                     North Indian, Chinese, Mughlai            900
# 1963  Cafe, North Indian, Chinese, Kashmiri, Rolls, ...            800
# 1964                        Pizza, Fast Food, Beverages            500
#
#                                          Locality  Dining_Rating  \
# 0                                  ITO, New Delhi            4.9
# 1                       Pragati Maidan, New Delhi            4.9
# 2             ITC Maurya, Chanakyapuri, New Delhi            4.9
# 3              Cyber Hub, DLF Cyber City, Gurgaon            4.9
# 4                          Khan Market, New Delhi            4.9
# ...                                           ...            ...
# 1960               Ashok Vihar Phase 3, New Delhi            3.9
# 1961                    Dilshad Garden, New Delhi            3.9
# 1962   Basant Lok Market, Vasant Vihar, New Delhi            3.9
# 1963                      Sainik Farms, New Delhi            3.9
# 1964                   Gaur City 2, Greater Noida            3.9
#
#                                             Known_For22
# 0                                                   NaN
# 1     Artistic Decor, The Service, Natural Ambience,...
# 2                                                   NaN
# 3     Knowledgeable Staff, Authentic, Soothing Ambie...
# 4     Retro Ambience, Yummy Desserts, Big Portions, ...
# ...                                                 ...
# 1960                                                NaN
# 1961  Lip Smacking Food, Amazing Food, Owner, Good P...
# 1962                                                NaN
# 1963                                                NaN
# 1964                                                NaN
#
# [1965 rows x 6 columns]

# %%
data.duplicated().sum()
data.drop_duplicates(inplace=True)
data.head()
# Out:
#           Restaurant_Name                                           Category  \
# 0                Rustom's  Parsi, Street Food, North Indian, Desserts, Be...
# 1               Cafe Lota        Cafe, South Indian, North Indian, Beverages
# 2  Dum-Pukht - ITC Maurya                    Mughlai, North Indian, Desserts
# 3             Burma Burma        Asian, Burmese, Bubble Tea, Desserts, Salad
# 4           The Big Chill                     Continental, American, Italian
#
#    Pricing_for_2                              Locality  Dining_Rating  \
# 0           2100                        ITO, New Delhi            4.9
# 1           1200             Pragati Maidan, New Delhi            4.9
# 2           5000   ITC Maurya, Chanakyapuri, New Delhi            4.9
# 3           1600    Cyber Hub, DLF Cyber City, Gurgaon            4.9
# 4           1500                Khan Market, New Delhi            4.9
#
#                                          Known_For22
# 0                                                NaN
# 1  Artistic Decor, The Service, Natural Ambience,...
# 2                                                NaN
# 3  Knowledgeable Staff, Authentic, Soothing Ambie...
# 4  Retro Ambience, Yummy Desserts, Big Portions, ...

# %%
data.isnull().sum()
# Out:
# Restaurant_Name      0
# Category             0
# Pricing_for_2        0
# Locality             0
# Dining_Rating        0
# Known_For22        841
# dtype: int64

# %%
data.dropna(how='any',inplace=True)
data.head()
# Out:
#                  Restaurant_Name                                     Category  \
# 1                      Cafe Lota  Cafe, South Indian, North Indian, Beverages
# 3                    Burma Burma  Asian, Burmese, Bubble Tea, Desserts, Salad
# 4                  The Big Chill               Continental, American, Italian
# 5                  Carnatic Cafe                                 South Indian
# 6  Cocktails & Dreams, Speakeasy                 Nepalese, Tibetan, Beverages
#
#    Pricing_for_2                             Locality  Dining_Rating  \
# 1           1200            Pragati Maidan, New Delhi            4.9
# 3           1600   Cyber Hub, DLF Cyber City, Gurgaon            4.9
# 4           1500               Khan Market, New Delhi            4.9
# 5            600              Lodhi Colony, New Delhi            4.9
# 6           2500                   Sector 15, Gurgaon            4.9
#
#                                          Known_For22
# 1  Artistic Decor, The Service, Natural Ambience,...
# 3  Knowledgeable Staff, Authentic, Soothing Ambie...
# 4  Retro Ambience, Yummy Desserts, Big Portions, ...
# 5  Cosy Ambience, Live Kitchen, Quiet Place, Calm...
# 6  Jazz Music, Band Playing, Bartender, Live Band...

# %%
data.isnull().sum()
# Out:
# Restaurant_Name    0
# Category           0
# Pricing_for_2      0
# Locality           0
# Dining_Rating      0
# Known_For22        0
# dtype: int64

# %%
data = data.rename(columns={'Restaurant_Name':'name','Category':'cuisines','Pricing_for_2':'cost','Locality':'location', 'Dining_Rating':'rating', 'Known_For22':'reviews_list'})

# %%
data.head()
# Out:
#                             name                                     cuisines  \
# 1                      Cafe Lota  Cafe, South Indian, North Indian, Beverages
# 3                    Burma Burma  Asian, Burmese, Bubble Tea, Desserts, Salad
# 4                  The Big Chill               Continental, American, Italian
# 5                  Carnatic Cafe                                 South Indian
# 6  Cocktails & Dreams, Speakeasy                 Nepalese, Tibetan, Beverages
#
#    cost                             location  rating  \
# 1  1200            Pragati Maidan, New Delhi     4.9
# 3  1600   Cyber Hub, DLF Cyber City, Gurgaon     4.9
# 4  1500               Khan Market, New Delhi     4.9
# 5   600              Lodhi Colony, New Delhi     4.9
# 6  2500                   Sector 15, Gurgaon     4.9
#
#                                         reviews_list
# 1  Artistic Decor, The Service, Natural Ambience,...
# 3  Knowledgeable Staff, Authentic, Soothing Ambie...
# 4  Retro Ambience, Yummy Desserts, Big Portions, ...
# 5  Cosy Ambience, Live Kitchen, Quiet Place, Calm...
# 6  Jazz Music, Band Playing, Bartender, Live Band...

# %%
data.name = data.name.apply(lambda x:x.title())

# %%
data['cost'] = data['cost'].astype(float)

# %%
restaurants = list(data['name'].unique())
data['Mean Rating'] = 0

for i in range(len(restaurants)):
    data['Mean Rating'][data['name'] == restaurants[i]] = data['rating'][data['name'] == restaurants[i]].mean()

# %%
data
# Out:
#                                name  \
# 1                         Cafe Lota
# 3                       Burma Burma
# 4                     The Big Chill
# 5                     Carnatic Cafe
# 6     Cocktails & Dreams, Speakeasy
# ...                             ...
# 1952             Aman-Deep Pure Veg
# 1953               All Biryani King
# 1955                  Chilli Dragon
# 1956                    Playboy Tap
# 1961                      Kovilakam
#
#                                          cuisines    cost  \
# 1     Cafe, South Indian, North Indian, Beverages  1200.0
# 3     Asian, Burmese, Bubble Tea, Desserts, Salad  1600.0
# 4                  Continental, American, Italian  1500.0
# 5                                    South Indian   600.0
# 6                    Nepalese, Tibetan, Beverages  2500.0
# ...                                           ...     ...
# 1952                        North Indian, Chinese   400.0
# 1953                        Mughlai, North Indian   400.0
# 1955              Chinese, Tibetan, Thai, Seafood   700.0
# 1956                        European, Continental  1600.0
# 1961                                 South Indian   350.0
#
#                                            location  rating  \
# 1                         Pragati Maidan, New Delhi     4.9
# 3                Cyber Hub, DLF Cyber City, Gurgaon     4.9
# 4                            Khan Market, New Delhi     4.9
# 5                           Lodhi Colony, New Delhi     4.9
# 6                                Sector 15, Gurgaon     4.9
# ...                                             ...     ...
# 1952                       Shalimar Bagh, New Delhi     3.9
# 1953                         Uttam Nagar, New Delhi     3.9
# 1955                       Malviya Nagar, New Delhi     3.9
# 1956   Global Foyer Mall, Golf Course Road, Gurgaon     3.9
# 1961                      Dilshad Garden, New Delhi     3.9
#
#                                            reviews_list  Mean Rating
# 1     Artistic Decor, The Service, Natural Ambience,...          4.9
# 3     Knowledgeable Staff, Authentic, Soothing Ambie...          4.9
# 4     Retro Ambience, Yummy Desserts, Big Portions, ...          4.9
# 5     Cosy Ambience, Live Kitchen, Quiet Place, Calm...          4.9
# 6     Jazz Music, Band Playing, Bartender, Live Band...          4.9
# ...                                                 ...          ...
# 1952  Seating, Worth the Money, Prices, Timely Servi...          3.9
# 1953  Variety of Pizza, Customizable Dishes, Weekend...          3.9
# 1955  Casual Seating Area, Chinese Restaurant, Nice ...          3.9
# 1956  Live Entertainment, Good Bartenders, Beautiful...          3.9
# 1961  Lip Smacking Food, Amazing Food, Owner, Good P...          3.9
#
# [1124 rows x 7 columns]

# %%
data.loc[data.name =='Burma Burma']
# Out:
#           name                                     cuisines    cost  \
# 3  Burma Burma  Asian, Burmese, Bubble Tea, Desserts, Salad  1600.0
#
#                               location  rating  \
# 3   Cyber Hub, DLF Cyber City, Gurgaon     4.9
#
#                                         reviews_list  Mean Rating
# 3  Knowledgeable Staff, Authentic, Soothing Ambie...          4.9

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (1,5))
data[['Mean Rating']] = scaler.fit_transform(data[['Mean Rating']]).round(2)

# %%
data.head()
# Out:
#                             name                                     cuisines  \
# 1                      Cafe Lota  Cafe, South Indian, North Indian, Beverages
# 3                    Burma Burma  Asian, Burmese, Bubble Tea, Desserts, Salad
# 4                  The Big Chill               Continental, American, Italian
# 5                  Carnatic Cafe                                 South Indian
# 6  Cocktails & Dreams, Speakeasy                 Nepalese, Tibetan, Beverages
#
#      cost                             location  rating  \
# 1  1200.0            Pragati Maidan, New Delhi     4.9
# 3  1600.0   Cyber Hub, DLF Cyber City, Gurgaon     4.9
# 4  1500.0               Khan Market, New Delhi     4.9
# 5   600.0              Lodhi Colony, New Delhi     4.9
# 6  2500.0                   Sector 15, Gurgaon     4.9
#
#                                         reviews_list  Mean Rating
# 1  Artistic Decor, The Service, Natural Ambience,...          5.0
# 3  Knowledgeable Staff, Authentic, Soothing Ambie...          5.0
# 4  Retro Ambience, Yummy Desserts, Big Portions, ...          5.0
# 5  Cosy Ambience, Live Kitchen, Quiet Place, Calm...          5.0
# 6  Jazz Music, Band Playing, Bartender, Live Band...          5.0

# %%
#Before Text Processing
data[['reviews_list', 'cuisines']].head()
# Out:
#                                         reviews_list  \
# 1  Artistic Decor, The Service, Natural Ambience,...
# 3  Knowledgeable Staff, Authentic, Soothing Ambie...
# 4  Retro Ambience, Yummy Desserts, Big Portions, ...
# 5  Cosy Ambience, Live Kitchen, Quiet Place, Calm...
# 6  Jazz Music, Band Playing, Bartender, Live Band...
#
#                                       cuisines
# 1  Cafe, South Indian, North Indian, Beverages
# 3  Asian, Burmese, Bubble Tea, Desserts, Salad
# 4               Continental, American, Italian
# 5                                 South Indian
# 6                 Nepalese, Tibetan, Beverages

# %%
#Lower Casing
data["reviews_list"] = data["reviews_list"].str.lower()

#Removal of Punctuations 
import string
punc = string.punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans('', '', punc))

data["reviews_list"] = data["reviews_list"].apply(lambda text: remove_punctuation(text))

#Removal of Stopwords
Stopwords = set(stopwords.words('english'))
def remove_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in Stopwords])

data["reviews_list"] = data["reviews_list"].apply(lambda text: remove_stopwords(text))

#Removal of URLS
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

data["reviews_list"] = data["reviews_list"].apply(lambda text: remove_urls(text))
data[['reviews_list', 'cuisines']].head()
# Out:
#                                         reviews_list  \
# 1  artistic decor service natural ambience fusion...
# 3  knowledgeable staff authentic soothing ambienc...
# 4  retro ambience yummy desserts big portions big...
# 5  cosy ambience live kitchen quiet place calm co...
# 6  jazz music band playing bartender live band li...
#
#                                       cuisines
# 1  Cafe, South Indian, North Indian, Beverages
# 3  Asian, Burmese, Bubble Tea, Desserts, Salad
# 4               Continental, American, Italian
# 5                                 South Indian
# 6                 Nepalese, Tibetan, Beverages

# %% [markdown]
# # Recommendation by Reviews

# %%
data
# Out:
#                                name  \
# 1                         Cafe Lota
# 3                       Burma Burma
# 4                     The Big Chill
# 5                     Carnatic Cafe
# 6     Cocktails & Dreams, Speakeasy
# ...                             ...
# 1952             Aman-Deep Pure Veg
# 1953               All Biryani King
# 1955                  Chilli Dragon
# 1956                    Playboy Tap
# 1961                      Kovilakam
#
#                                          cuisines    cost  \
# 1     Cafe, South Indian, North Indian, Beverages  1200.0
# 3     Asian, Burmese, Bubble Tea, Desserts, Salad  1600.0
# 4                  Continental, American, Italian  1500.0
# 5                                    South Indian   600.0
# 6                    Nepalese, Tibetan, Beverages  2500.0
# ...                                           ...     ...
# 1952                        North Indian, Chinese   400.0
# 1953                        Mughlai, North Indian   400.0
# 1955              Chinese, Tibetan, Thai, Seafood   700.0
# 1956                        European, Continental  1600.0
# 1961                                 South Indian   350.0
#
#                                            location  rating  \
# 1                         Pragati Maidan, New Delhi     4.9
# 3                Cyber Hub, DLF Cyber City, Gurgaon     4.9
# 4                            Khan Market, New Delhi     4.9
# 5                           Lodhi Colony, New Delhi     4.9
# 6                                Sector 15, Gurgaon     4.9
# ...                                             ...     ...
# 1952                       Shalimar Bagh, New Delhi     3.9
# 1953                         Uttam Nagar, New Delhi     3.9
# 1955                       Malviya Nagar, New Delhi     3.9
# 1956   Global Foyer Mall, Golf Course Road, Gurgaon     3.9
# 1961                      Dilshad Garden, New Delhi     3.9
#
#                                            reviews_list  Mean Rating
# 1     artistic decor service natural ambience fusion...          5.0
# 3     knowledgeable staff authentic soothing ambienc...          5.0
# 4     retro ambience yummy desserts big portions big...          5.0
# 5     cosy ambience live kitchen quiet place calm co...          5.0
# 6     jazz music band playing bartender live band li...          5.0
# ...                                                 ...          ...
# 1952  seating worth money prices timely service quan...          1.0
# 1953  variety pizza customizable dishes weekend brun...          1.0
# 1955  casual seating area chinese restaurant nice cr...          1.0
# 1956  live entertainment good bartenders beautiful i...          1.0
# 1961  lip smacking food amazing food owner good plac...          1.0
#
# [1124 rows x 7 columns]

# %%
df_percent = data.sample(frac=1)
df_percent.set_index('name', inplace=True)
indices = pd.Series(df_percent.index)

# %%
tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1, 2), min_df=1, stop_words='english')
tfidf_matrix = tfidf.fit_transform(df_percent['reviews_list'])
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
df_percent
# Out:
#                                                                            cuisines  \
# name
# Oh! Assam                                                            Assamese, Naga
# The Big Chill                                        Continental, American, Italian
# Natural Ice Cream                                               Ice Cream, Desserts
# The Breakfast Club                                  Cafe, North Indian, Continental
# Brownie Heaven                                                             Desserts
# ...                                                                             ...
# Culinaria By Pikwik                        North Indian, Chinese, Continental, Thai
# The Backyard                                          Italian, Mexican, Continental
# @ Links - Radisson Blu                                Finger Food, Pizza, Beverages
# Creo - Vivanta New Delhi, Dwarka                       Italian, North Indian, Asian
# Kuch Bhi Chalega                  Chinese, Fast Food, Street Food, Momos, Beverages
#
#                                     cost  \
# name
# Oh! Assam                          400.0
# The Big Chill                     1500.0
# Natural Ice Cream                  400.0
# The Breakfast Club                 800.0
# Brownie Heaven                     300.0
# ...                                  ...
# Culinaria By Pikwik               1000.0
# The Backyard                      1800.0
# @ Links - Radisson Blu            4500.0
# Creo - Vivanta New Delhi, Dwarka  3000.0
# Kuch Bhi Chalega                   600.0
#
#                                                                 location  \
# name
# Oh! Assam                                          Safdarjung, New Delhi
# The Big Chill                                     Khan Market, New Delhi
# Natural Ice Cream                             Connaught Place, New Delhi
# The Breakfast Club                    DLF Galleria, DLF Phase 4, Gurgaon
# Brownie Heaven                                   Punjabi Bagh, New Delhi
# ...                                                                  ...
# Culinaria By Pikwik                                 Pitampura, New Delhi
# The Backyard                                     Punjabi Bagh, New Delhi
# @ Links - Radisson Blu             Radisson Blu, Sector 18, Noida, Noida
# Creo - Vivanta New Delhi, Dwarka    Vivanta New Delhi, Dwarka, New Delhi
# Kuch Bhi Chalega                                    Janakpuri, New Delhi
#
#                                   rating  \
# name
# Oh! Assam                            3.9
# The Big Chill                        4.9
# Natural Ice Cream                    4.9
# The Breakfast Club                   3.9
# Brownie Heaven                       3.9
# ...                                  ...
# Culinaria By Pikwik                  4.0
# The Backyard                         4.0
# @ Links - Radisson Blu               3.9
# Creo - Vivanta New Delhi, Dwarka     4.0
# Kuch Bhi Chalega                     4.1
#
#                                                                        reviews_list  \
# name
# Oh! Assam                         pretty decor self service young crowd cafe pri...
# The Big Chill                     retro ambience yummy desserts big portions big...
# Natural Ice Cream                 bank buck totally worth coffee date table serv...
# The Breakfast Club                affordable rate cozy ambiance economical booki...
# Brownie Heaven                    cashless payments nice concept delicious taste...
# ...                                                                             ...
# Culinaria By Pikwik               pocket friendly casual seating area crowded fa...
# The Backyard                      variety veg options good large groups relaxed ...
# @ Links - Radisson Blu            good large groups comfortable seating area fam...
# Creo - Vivanta New Delhi, Dwarka  music feel great recommendations customizable ...
# Kuch Bhi Chalega                  pocket friendly place elegantly decorated serv...
#
#                                   Mean Rating
# name
# Oh! Assam                                 1.0
# The Big Chill                             5.0
# Natural Ice Cream                         5.0
# The Breakfast Club                        1.0
# Brownie Heaven                            1.0
# ...                                       ...
# Culinaria By Pikwik                       1.4
# The Backyard                              1.4
# @ Links - Radisson Blu                    1.0
# Creo - Vivanta New Delhi, Dwarka          1.4
# Kuch Bhi Chalega                          1.8
#
# [1124 rows x 6 columns]

# %%
def recommend_like(name, top_n=10, cosine_similarities=cosine_similarities):
    recommend_restaurant = []
    try:
        idx = indices[indices == name].index[0]
        score_series = pd.Series(cosine_similarities[idx])
        top_indexes = list(score_series.iloc[1:top_n+1].index)

        for each in top_indexes:
            recommend_restaurant.append(list(df_percent.index)[each])

        df_new = pd.DataFrame(columns=['name', 'cuisines', 'Mean Rating', 'cost'])
        for each in recommend_restaurant:
            selected_data = df_percent.loc[df_percent.index == each, ['cuisines', 'Mean Rating', 'cost']].sample()
            selected_data['name'] = each 
            df_new = pd.concat([df_new, selected_data])
        df_new = df_new.drop_duplicates(subset=['name', 'cuisines', 'Mean Rating', 'cost'], keep=False)
        df_new = df_new.sort_values(by='Mean Rating', ascending=False).head(top_n)

        print(f'TOP RESTAURANTS LIKE {name.upper()}: ')
        return df_new.style.hide_index()
    except:
        print('No restaurants with similar reviews.')

# %%
recommend_like('The Big Chill')
# Out:
# TOP RESTAURANTS LIKE THE BIG CHILL:
# <style type="text/css">
# </style>
# <table id="T_4d0ee">
#   <thead>
#     <tr>
#       <th id="T_4d0ee_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_4d0ee_level0_col1" class="col_heading level0 col1" >cuisines</th>
#       <th id="T_4d0ee_level0_col2" class="col_heading level0 col2" >Mean Rating</th>
#       <th id="T_4d0ee_level0_col3" class="col_heading level0 col3" >cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4d0ee_row0_col0" class="data row0 col0" >The Big Chill</td>
#       <td id="T_4d0ee_row0_col1" class="data row0 col1" >Continental, American, Italian</td>
#       <td id="T_4d0ee_row0_col2" class="data row0 col2" >5.000000</td>
#       <td id="T_4d0ee_row0_col3" class="data row0 col3" >1500.000000</td>
#     </tr>
#     <tr>
#       <td id="T_4d0ee_row1_col0" class="data row1 col0" >Natural Ice Cream</td>
#       <td id="T_4d0ee_row1_col1" class="data row1 col1" >Ice Cream, Desserts</td>
#       <td id="T_4d0ee_row1_col2" class="data row1 col2" >5.000000</td>
#       <td id="T_4d0ee_row1_col3" class="data row1 col3" >400.000000</td>
#     </tr>
#     <tr>
#       <td id="T_4d0ee_row2_col0" class="data row2 col0" >Cervesia</td>
#       <td id="T_4d0ee_row2_col1" class="data row2 col1" >North Indian, Continental, Chinese</td>
#       <td id="T_4d0ee_row2_col2" class="data row2 col2" >2.600000</td>
#       <td id="T_4d0ee_row2_col3" class="data row2 col3" >1900.000000</td>
#     </tr>
#     <tr>
#       <td id="T_4d0ee_row3_col0" class="data row3 col0" >The Sweeet Jar</td>
#       <td id="T_4d0ee_row3_col1" class="data row3 col1" >Cafe, Chinese, Italian, Fast Food, Sandwich, Burger, Beverages</td>
#       <td id="T_4d0ee_row3_col2" class="data row3 col2" >2.200000</td>
#       <td id="T_4d0ee_row3_col3" class="data row3 col3" >800.000000</td>
#     </tr>
#     <tr>
#       <td id="T_4d0ee_row4_col0" class="data row4 col0" >Too Indian</td>
#       <td id="T_4d0ee_row4_col1" class="data row4 col1" >North Indian, Continental</td>
#       <td id="T_4d0ee_row4_col2" class="data row4 col2" >1.800000</td>
#       <td id="T_4d0ee_row4_col3" class="data row4 col3" >1400.000000</td>
#     </tr>
#     <tr>
#       <td id="T_4d0ee_row5_col0" class="data row5 col0" >Grubhouse Cafe</td>
#       <td id="T_4d0ee_row5_col1" class="data row5 col1" >Italian, Chinese, Sandwich, Burger, Rolls, Momos, Pizza, Beverages</td>
#       <td id="T_4d0ee_row5_col2" class="data row5 col2" >1.400000</td>
#       <td id="T_4d0ee_row5_col3" class="data row5 col3" >500.000000</td>
#     </tr>
#     <tr>
#       <td id="T_4d0ee_row6_col0" class="data row6 col0" >The Dessert Studio</td>
#       <td id="T_4d0ee_row6_col1" class="data row6 col1" >Bakery, Desserts</td>
#       <td id="T_4d0ee_row6_col2" class="data row6 col2" >1.400000</td>
#       <td id="T_4d0ee_row6_col3" class="data row6 col3" >400.000000</td>
#     </tr>
#     <tr>
#       <td id="T_4d0ee_row7_col0" class="data row7 col0" >The Breakfast Club</td>
#       <td id="T_4d0ee_row7_col1" class="data row7 col1" >Cafe, North Indian, Continental</td>
#       <td id="T_4d0ee_row7_col2" class="data row7 col2" >1.000000</td>
#       <td id="T_4d0ee_row7_col3" class="data row7 col3" >800.000000</td>
#     </tr>
#     <tr>
#       <td id="T_4d0ee_row8_col0" class="data row8 col0" >Brownie Heaven</td>
#       <td id="T_4d0ee_row8_col1" class="data row8 col1" >Desserts</td>
#       <td id="T_4d0ee_row8_col2" class="data row8 col2" >1.000000</td>
#       <td id="T_4d0ee_row8_col3" class="data row8 col3" >300.000000</td>
#     </tr>
#     <tr>
#       <td id="T_4d0ee_row9_col0" class="data row9 col0" >Moustache Coffee</td>
#       <td id="T_4d0ee_row9_col1" class="data row9 col1" >Cafe, Continental, Italian</td>
#       <td id="T_4d0ee_row9_col2" class="data row9 col2" >1.000000</td>
#       <td id="T_4d0ee_row9_col3" class="data row9 col3" >400.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Recommendation by Cuisine

# %%
df_percent = data.sample(frac=1)
df_percent.set_index('cuisines'.lower(), inplace=True) 
indices = pd.Series(df_percent.index)

from fuzzywuzzy import fuzz

cuisine_mapping = {}
for index, row in data.iterrows():
    for cuisine in row['cuisines'].split(', '):
        normalized_cuisine = cuisine.lower()
        if normalized_cuisine not in cuisine_mapping:
            cuisine_mapping[normalized_cuisine] = []
        cuisine_mapping[normalized_cuisine].append(index)

def recommend_by_cuisine(criteria_value, top_n=10, cosine_similarities=cosine_similarities):
    recommend_restaurant = []
    normalized_criteria = criteria_value.lower()
    matching_restaurants = cuisine_mapping.get(normalized_criteria, [])

    for restaurant_index in matching_restaurants:
        recommend_restaurant.append(restaurant_index)

    df_new = pd.DataFrame(columns=['name', 'cuisines', 'Mean Rating', 'cost'])
    for each in recommend_restaurant:
        selected_data = data[['name', 'cuisines', 'Mean Rating', 'cost']][data.index == each].sample()
        df_new = pd.concat([df_new, selected_data])
    df_new = df_new.drop_duplicates(subset=['name', 'cuisines', 'Mean Rating', 'cost'], keep=False)
    df_new = df_new.sort_values(by='Mean Rating', ascending=False).head(top_n)

    print(f'TOP RESTAURANTS WITH SIMILAR CUISINE: ')
    df_new.reset_index(drop=True)

    return df_new.style.hide_index()

# %%
recommend_by_cuisine('Chinese')
# Out:
# TOP RESTAURANTS WITH SIMILAR CUISINE:
# <style type="text/css">
# </style>
# <table id="T_ed690">
#   <thead>
#     <tr>
#       <th id="T_ed690_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_ed690_level0_col1" class="col_heading level0 col1" >cuisines</th>
#       <th id="T_ed690_level0_col2" class="col_heading level0 col2" >Mean Rating</th>
#       <th id="T_ed690_level0_col3" class="col_heading level0 col3" >cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ed690_row0_col0" class="data row0 col0" >Spezia Bistro</td>
#       <td id="T_ed690_row0_col1" class="data row0 col1" >Pizza, Chinese, Momos, Fast Food, Italian, Beverages, Continental</td>
#       <td id="T_ed690_row0_col2" class="data row0 col2" >4.200000</td>
#       <td id="T_ed690_row0_col3" class="data row0 col3" >900.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ed690_row1_col0" class="data row1 col0" >Master Koii'S</td>
#       <td id="T_ed690_row1_col1" class="data row1 col1" >Asian, Chinese, Thai, Malaysian, Korean</td>
#       <td id="T_ed690_row1_col2" class="data row1 col2" >4.200000</td>
#       <td id="T_ed690_row1_col3" class="data row1 col3" >1900.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ed690_row2_col0" class="data row2 col0" >Downtown - Diners & Living Beer Cafe</td>
#       <td id="T_ed690_row2_col1" class="data row2 col1" >Bar Food, North Indian, Fast Food, Italian, Chinese, Beverages</td>
#       <td id="T_ed690_row2_col2" class="data row2 col2" >4.200000</td>
#       <td id="T_ed690_row2_col3" class="data row2 col3" >2200.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ed690_row3_col0" class="data row3 col0" >Plum By Bent Chair</td>
#       <td id="T_ed690_row3_col1" class="data row3 col1" >Chinese, Japanese, Thai, Asian, Beverages</td>
#       <td id="T_ed690_row3_col2" class="data row3 col2" >3.800000</td>
#       <td id="T_ed690_row3_col3" class="data row3 col3" >2200.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ed690_row4_col0" class="data row4 col0" >Noida Social</td>
#       <td id="T_ed690_row4_col1" class="data row4 col1" >North Indian, Chinese, Burger, Rolls, Pizza, Momos, Continental, Beverages</td>
#       <td id="T_ed690_row4_col2" class="data row4 col2" >3.800000</td>
#       <td id="T_ed690_row4_col3" class="data row4 col3" >1300.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ed690_row5_col0" class="data row5 col0" >K3 - Jw Marriott New Delhi</td>
#       <td id="T_ed690_row5_col1" class="data row5 col1" >North Indian, Chinese, Italian, Momos</td>
#       <td id="T_ed690_row5_col2" class="data row5 col2" >3.800000</td>
#       <td id="T_ed690_row5_col3" class="data row5 col3" >3500.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ed690_row6_col0" class="data row6 col0" >The Yellow Chilli</td>
#       <td id="T_ed690_row6_col1" class="data row6 col1" >North Indian, Mughlai, Chinese, Beverages, Desserts, Kebab</td>
#       <td id="T_ed690_row6_col2" class="data row6 col2" >3.800000</td>
#       <td id="T_ed690_row6_col3" class="data row6 col3" >1600.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ed690_row7_col0" class="data row7 col0" >You Mee</td>
#       <td id="T_ed690_row7_col1" class="data row7 col1" >Japanese, Sushi, Asian, Chinese, Thai, Beverages</td>
#       <td id="T_ed690_row7_col2" class="data row7 col2" >3.800000</td>
#       <td id="T_ed690_row7_col3" class="data row7 col3" >1000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ed690_row8_col0" class="data row8 col0" >Open Tap</td>
#       <td id="T_ed690_row8_col1" class="data row8 col1" >Finger Food, North Indian, Chinese, Italian, Bar Food</td>
#       <td id="T_ed690_row8_col2" class="data row8 col2" >3.530000</td>
#       <td id="T_ed690_row8_col3" class="data row8 col3" >2000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ed690_row9_col0" class="data row9 col0" >Berco'S</td>
#       <td id="T_ed690_row9_col1" class="data row9 col1" >Chinese, Thai, Asian, Beverages</td>
#       <td id="T_ed690_row9_col2" class="data row9 col2" >3.400000</td>
#       <td id="T_ed690_row9_col3" class="data row9 col3" >900.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Recommendation by Rating

# %%
df_percent = data.sample(frac=1)
df_percent.set_index('Mean Rating', inplace=True) 
indices = pd.Series(df_percent.index)

def recommend_by_mean_rating(mean_rating_value, top_n=10):
    recommend_restaurant = data[data['Mean Rating'] >= mean_rating_value].index
    df_new = data.loc[recommend_restaurant, ['name', 'cuisines', 'Mean Rating', 'cost']]
    df_new = df_new.sample(frac=1) 
    df_new = df_new.head(top_n)
    print(f'TOP RESTAURANTS WITH A MINIMUM RATING OF {mean_rating_value}: ')
    df_new.reset_index(drop=True, inplace=True)
    return df_new.style.hide_index()

# %%
recommend_by_mean_rating(4)
# Out:
# TOP RESTAURANTS WITH A MINIMUM RATING OF 4:
# <style type="text/css">
# </style>
# <table id="T_9c17e">
#   <thead>
#     <tr>
#       <th id="T_9c17e_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_9c17e_level0_col1" class="col_heading level0 col1" >cuisines</th>
#       <th id="T_9c17e_level0_col2" class="col_heading level0 col2" >Mean Rating</th>
#       <th id="T_9c17e_level0_col3" class="col_heading level0 col3" >cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9c17e_row0_col0" class="data row0 col0" >Kunzum Travel Cafe</td>
#       <td id="T_9c17e_row0_col1" class="data row0 col1" >Cafe</td>
#       <td id="T_9c17e_row0_col2" class="data row0 col2" >4.200000</td>
#       <td id="T_9c17e_row0_col3" class="data row0 col3" >500.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9c17e_row1_col0" class="data row1 col0" >Carnatic Cafe</td>
#       <td id="T_9c17e_row1_col1" class="data row1 col1" >South Indian</td>
#       <td id="T_9c17e_row1_col2" class="data row1 col2" >5.000000</td>
#       <td id="T_9c17e_row1_col3" class="data row1 col3" >600.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9c17e_row2_col0" class="data row2 col0" >Cocktails & Dreams, Speakeasy</td>
#       <td id="T_9c17e_row2_col1" class="data row2 col1" >Nepalese, Tibetan, Beverages</td>
#       <td id="T_9c17e_row2_col2" class="data row2 col2" >5.000000</td>
#       <td id="T_9c17e_row2_col3" class="data row2 col3" >2500.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9c17e_row3_col0" class="data row3 col0" >Natural Ice Cream</td>
#       <td id="T_9c17e_row3_col1" class="data row3 col1" >Ice Cream, Desserts</td>
#       <td id="T_9c17e_row3_col2" class="data row3 col2" >5.000000</td>
#       <td id="T_9c17e_row3_col3" class="data row3 col3" >400.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9c17e_row4_col0" class="data row4 col0" >The Big Chill Cakery</td>
#       <td id="T_9c17e_row4_col1" class="data row4 col1" >Bakery, Desserts</td>
#       <td id="T_9c17e_row4_col2" class="data row4 col2" >4.600000</td>
#       <td id="T_9c17e_row4_col3" class="data row4 col3" >400.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9c17e_row5_col0" class="data row5 col0" >Olive Bar & Kitchen</td>
#       <td id="T_9c17e_row5_col1" class="data row5 col1" >Italian, Pizza, Mediterranean, Continental, European, Beverages, Desserts</td>
#       <td id="T_9c17e_row5_col2" class="data row5 col2" >4.200000</td>
#       <td id="T_9c17e_row5_col3" class="data row5 col3" >4000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9c17e_row6_col0" class="data row6 col0" >Yum Yum Cha</td>
#       <td id="T_9c17e_row6_col1" class="data row6 col1" >Asian, Japanese, Sushi, Desserts, Beverages, Rolls</td>
#       <td id="T_9c17e_row6_col2" class="data row6 col2" >4.600000</td>
#       <td id="T_9c17e_row6_col3" class="data row6 col3" >1800.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9c17e_row7_col0" class="data row7 col0" >Spezia Bistro</td>
#       <td id="T_9c17e_row7_col1" class="data row7 col1" >Pizza, Chinese, Momos, Fast Food, Italian, Beverages, Continental</td>
#       <td id="T_9c17e_row7_col2" class="data row7 col2" >4.200000</td>
#       <td id="T_9c17e_row7_col3" class="data row7 col3" >900.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9c17e_row8_col0" class="data row8 col0" >Evoo - Eatery And Pizzeria</td>
#       <td id="T_9c17e_row8_col1" class="data row8 col1" >Cafe, Italian, Desserts, Beverages</td>
#       <td id="T_9c17e_row8_col2" class="data row8 col2" >4.200000</td>
#       <td id="T_9c17e_row8_col3" class="data row8 col3" >1500.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9c17e_row9_col0" class="data row9 col0" >The Grammar Room</td>
#       <td id="T_9c17e_row9_col1" class="data row9 col1" >Continental, Desserts, Beverages</td>
#       <td id="T_9c17e_row9_col2" class="data row9 col2" >4.200000</td>
#       <td id="T_9c17e_row9_col3" class="data row9 col3" >1200.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Recommendation by Cost

# %%
df_percent = data.sample(frac=1)
df_percent.set_index('cost', inplace=True)  
indices = pd.Series(df_percent.index)

def recommend_by_cost(min_value,max_value, top_n=-1):
    recommend_restaurant = data[(data['cost'] > min_value) & (data['cost'] <= max_value)].index
    df_new = data.loc[recommend_restaurant, ['name', 'cuisines', 'Mean Rating', 'cost']]
    df_new = df_new.sample(frac=1) 
    df_new = df_new.head(top_n)
    print(f'TOP RESTAURANTS IN THE PROVIDED RANGE: ')
    df_new.reset_index(drop=True, inplace=True)
    return df_new.style.hide_index()

# %%
recommend_by_cost(3000,4000)
# Out:
# TOP RESTAURANTS IN THE PROVIDED RANGE:
# <style type="text/css">
# </style>
# <table id="T_ff5bd">
#   <thead>
#     <tr>
#       <th id="T_ff5bd_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_ff5bd_level0_col1" class="col_heading level0 col1" >cuisines</th>
#       <th id="T_ff5bd_level0_col2" class="col_heading level0 col2" >Mean Rating</th>
#       <th id="T_ff5bd_level0_col3" class="col_heading level0 col3" >cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ff5bd_row0_col0" class="data row0 col0" >Paatra - Jaypee Siddharth</td>
#       <td id="T_ff5bd_row0_col1" class="data row0 col1" >North Indian</td>
#       <td id="T_ff5bd_row0_col2" class="data row0 col2" >1.400000</td>
#       <td id="T_ff5bd_row0_col3" class="data row0 col3" >3500.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row1_col0" class="data row1 col0" >Saffron - Trident Gurgaon</td>
#       <td id="T_ff5bd_row1_col1" class="data row1 col1" >North Indian, South Indian, Kebab, Mughlai, Beverages, Desserts</td>
#       <td id="T_ff5bd_row1_col2" class="data row1 col2" >1.800000</td>
#       <td id="T_ff5bd_row1_col3" class="data row1 col3" >3200.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row2_col0" class="data row2 col0" >Larry'S China - Ambassador</td>
#       <td id="T_ff5bd_row2_col1" class="data row2 col1" >Chinese, Seafood, Desserts</td>
#       <td id="T_ff5bd_row2_col2" class="data row2 col2" >1.400000</td>
#       <td id="T_ff5bd_row2_col3" class="data row2 col3" >4000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row3_col0" class="data row3 col0" >Grappa - Shangri-La'S - Eros Hotel, New Delhi</td>
#       <td id="T_ff5bd_row3_col1" class="data row3 col1" >Italian, Finger Food, Salad</td>
#       <td id="T_ff5bd_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_ff5bd_row3_col3" class="data row3 col3" >3500.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row4_col0" class="data row4 col0" >Tonino</td>
#       <td id="T_ff5bd_row4_col1" class="data row4 col1" >Italian, Pizza, Pasta, Salad, Beverages</td>
#       <td id="T_ff5bd_row4_col2" class="data row4 col2" >3.400000</td>
#       <td id="T_ff5bd_row4_col3" class="data row4 col3" >3500.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row5_col0" class="data row5 col0" >Frontier - The Ashok</td>
#       <td id="T_ff5bd_row5_col1" class="data row5 col1" >North Indian, Mughlai</td>
#       <td id="T_ff5bd_row5_col2" class="data row5 col2" >1.400000</td>
#       <td id="T_ff5bd_row5_col3" class="data row5 col3" >3600.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row6_col0" class="data row6 col0" >Tease - Taj City Centre Gurugram</td>
#       <td id="T_ff5bd_row6_col1" class="data row6 col1" >Finger Food</td>
#       <td id="T_ff5bd_row6_col2" class="data row6 col2" >1.400000</td>
#       <td id="T_ff5bd_row6_col3" class="data row6 col3" >3400.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row7_col0" class="data row7 col0" >Whisky Samba</td>
#       <td id="T_ff5bd_row7_col1" class="data row7 col1" >Asian, Sushi, Seafood, Desserts</td>
#       <td id="T_ff5bd_row7_col2" class="data row7 col2" >2.600000</td>
#       <td id="T_ff5bd_row7_col3" class="data row7 col3" >3800.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row8_col0" class="data row8 col0" >Cascades - The Grand New Delhi</td>
#       <td id="T_ff5bd_row8_col1" class="data row8 col1" >North Indian, Continental, Asian</td>
#       <td id="T_ff5bd_row8_col2" class="data row8 col2" >1.000000</td>
#       <td id="T_ff5bd_row8_col3" class="data row8 col3" >3200.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row9_col0" class="data row9 col0" >Elan - The Lodhi</td>
#       <td id="T_ff5bd_row9_col1" class="data row9 col1" >North Indian, Continental, Italian, Salad</td>
#       <td id="T_ff5bd_row9_col2" class="data row9 col2" >1.800000</td>
#       <td id="T_ff5bd_row9_col3" class="data row9 col3" >3500.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row10_col0" class="data row10 col0" >Spice Art - Crowne Plaza</td>
#       <td id="T_ff5bd_row10_col1" class="data row10 col1" >North Indian, Awadhi, Kebab, Mughlai, Asian, Beverages</td>
#       <td id="T_ff5bd_row10_col2" class="data row10 col2" >3.000000</td>
#       <td id="T_ff5bd_row10_col3" class="data row10 col3" >3500.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row11_col0" class="data row11 col0" >T.K'S Oriental Grill - Hyatt Regency</td>
#       <td id="T_ff5bd_row11_col1" class="data row11 col1" >Japanese, Thai, Sushi</td>
#       <td id="T_ff5bd_row11_col2" class="data row11 col2" >2.600000</td>
#       <td id="T_ff5bd_row11_col3" class="data row11 col3" >4000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row12_col0" class="data row12 col0" >Olive Bar & Kitchen</td>
#       <td id="T_ff5bd_row12_col1" class="data row12 col1" >Italian, Pizza, Mediterranean, Continental, European, Beverages, Desserts</td>
#       <td id="T_ff5bd_row12_col2" class="data row12 col2" >4.200000</td>
#       <td id="T_ff5bd_row12_col3" class="data row12 col3" >4000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row13_col0" class="data row13 col0" >Kebabs & Kurries - Welcomhotel Dwarka</td>
#       <td id="T_ff5bd_row13_col1" class="data row13 col1" >North Indian, Mughlai, Desserts</td>
#       <td id="T_ff5bd_row13_col2" class="data row13 col2" >1.800000</td>
#       <td id="T_ff5bd_row13_col3" class="data row13 col3" >3200.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row14_col0" class="data row14 col0" >Eest - The Westin Gurgaon</td>
#       <td id="T_ff5bd_row14_col1" class="data row14 col1" >Asian, Japanese, Thai, Chinese</td>
#       <td id="T_ff5bd_row14_col2" class="data row14 col2" >3.000000</td>
#       <td id="T_ff5bd_row14_col3" class="data row14 col3" >3500.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row15_col0" class="data row15 col0" >Rice - Radisson Blu Dwarka</td>
#       <td id="T_ff5bd_row15_col1" class="data row15 col1" >Chinese, Thai, Vietnamese, Japanese</td>
#       <td id="T_ff5bd_row15_col2" class="data row15 col2" >2.200000</td>
#       <td id="T_ff5bd_row15_col3" class="data row15 col3" >4000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row16_col0" class="data row16 col0" >Paatra - Jaypee Greens Golf & Spa Resort</td>
#       <td id="T_ff5bd_row16_col1" class="data row16 col1" >North Indian</td>
#       <td id="T_ff5bd_row16_col2" class="data row16 col2" >1.400000</td>
#       <td id="T_ff5bd_row16_col3" class="data row16 col3" >3500.000000</td>
#     </tr>
#     <tr>
#       <td id="T_ff5bd_row17_col0" class="data row17 col0" >K3 - Jw Marriott New Delhi</td>
#       <td id="T_ff5bd_row17_col1" class="data row17 col1" >North Indian, Chinese, Italian, Momos</td>
#       <td id="T_ff5bd_row17_col2" class="data row17 col2" >3.800000</td>
#       <td id="T_ff5bd_row17_col3" class="data row17 col3" >3500.000000</td>
#     </tr>
#   </tbody>
# </table>
